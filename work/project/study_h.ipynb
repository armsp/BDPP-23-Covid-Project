# %%
import pandas as pd

# %%
df = pd.read_csv( "data/owid-covid-data.csv", index_col = "date", parse_dates = True )
# Out:
# /tmp/ipykernel_1080/596705191.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv( "data/owid-covid-data.csv", index_col = "date", parse_dates = True )

# %%
country = df[ df.location == "Germany" ]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Outcomes

# %%
columns = [ "new_cases_smoothed_per_million", "new_deaths_smoothed_per_million", "weekly_hosp_admissions_per_million" ]
fig, axs = plt.subplots( 1, len( columns ), figsize = ( 4 * len( columns ), 4 ))
axs = axs.ravel( )

for i, c in enumerate( columns ):

    country[ c ].plot( title = c, ax = axs[ i ])

# %%
country.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# ### Measures

# %%
columns = [ "new_vaccinations_smoothed_per_million", "new_tests_smoothed_per_thousand" ]
fig, axs = plt.subplots( 1, len( columns ), figsize = ( 4 * len( columns ), 4 ))
axs = axs.ravel( )

for i, c in enumerate( columns ):

    country[ c ].plot( title = c, ax = axs[ i ])

# %%
df = pd.read_excel( "data/acaps_covid19_government_measures_dataset_0.xlsx", sheet_name = "Dataset", index_col = "DATE_IMPLEMENTED", parse_dates = True  )

# %%
country = df[ df.COUNTRY == "Germany" ]

# %%
country.MEASURE.unique()
# Out:
# array(['Strengthening the public health system', 'Economic measures',
#        'Other public health measures enforced', 'General recommendations',
#        'Awareness campaigns',
#        'Additional health/documents requirements upon arrival',
#        'Limit product imports/exports', 'Limit public gatherings',
#        'Border checks', 'Isolation and quarantine policies',
#        'Closure of businesses and public services', 'Border closure',
#        'Schools closure', 'State of emergency declared',
#        'Changes in prison-related policies', 'Partial lockdown',
#        'Emergency administrative structures activated or established',
#        'Military deployment', 'Surveillance and monitoring',
#        'Visa restrictions',
#        'Requirement to wear protective gear in public', 'Testing policy',
#        'Amendments to funeral and burial regulations',
#        'Health screenings in airports and border crossings', 'Curfews'],
#       dtype=object)

# %%
country.LOG_TYPE.unique()
# Out:
# array(['Introduction / extension of measures', 'Phase-out measure'],
#       dtype=object)

# %%
country
# Out:
#                       ID  ISO  COUNTRY  REGION ADMIN_LEVEL_NAME  PCODE
# DATE_IMPLEMENTED
# NaT                 3901  DEU  Germany  Europe              NaN    NaN  \
# NaT                 5620  DEU  Germany  Europe   Various states    NaN
# NaT                 8487  DEU  Germany  Europe              NaN    NaN
# NaT                 8479  DEU  Germany  Europe              NaN    NaN
# NaT                 9156  DEU  Germany  Europe              NaN    NaN
# ...                  ...  ...      ...     ...              ...    ...
# 2020-10-22        139697  DEU  Germany  Europe              NaN    NaN
# 2020-10-23        139698  DEU  Germany  Europe              NaN    NaN
# 2020-10-30        139680  DEU  Germany  Europe              NaN    NaN
# 2020-10-30        139681  DEU  Germany  Europe              NaN    NaN
# 2020-11-14        139590  DEU  Germany  Europe              NaN    NaN
#
#                                               LOG_TYPE
# DATE_IMPLEMENTED
# ...
